# %%
import pandas as pd

# %%
df1=pd.read_csv('backend/data/CPU_benchmark_v4.csv')
df1.head(2)
# Out:
#                              cpuName    price  cpuMark  cpuValue  threadMark  \
# 0  AMD Ryzen Threadripper PRO 5995WX      NaN   108822       NaN        3330
# 1                      AMD EPYC 7763  7299.99    88338      12.1        2635
#
#    threadValue    TDP powerPerf  cores  testDate socket category
# 0          NaN  280.0    388.65     64      2022  sWRX8  Desktop
# 1         0.36  280.0    315.49     64      2021    SP3   Server

# %%
df2=pd.read_csv('backend/data/gpu_specs_v7.csv')
df2.head(2)
# Out:
#   manufacturer       productName  releaseYear  memSize  memBusWidth  gpuClock  \
# 0       NVIDIA  GeForce RTX 5090       2025.0     28.0        448.0       900
# 1       NVIDIA  GeForce RTX 5080       2025.0     16.0        256.0       900
#
#    memClock  unifiedShader  tmu  rop  pixelShader  vertexShader igp  \
# 0    1200.0         8192.0  256  128          NaN           NaN  No
# 1    1215.0         6912.0  432  192          NaN           NaN  No
#
#             bus memType       gpuChip
# 0  PCIe 4.0 x16   HBM2e  Arctic Sound
# 1  PCIe 4.0 x16   HBM2e         GA100

# %%
print(df2.columns)
print(df1.columns)
# Out:
# Index(['manufacturer', 'productName', 'releaseYear', 'memSize', 'memBusWidth',
#        'gpuClock', 'memClock', 'unifiedShader', 'tmu', 'rop', 'pixelShader',
#        'vertexShader', 'igp', 'bus', 'memType', 'gpuChip'],
#       dtype='object')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 print(df2.columns)
# ----> 2 print(df1.columns())
#
# TypeError: 'Index' object is not callable

# %%
import os
from dotenv import load_dotenv

load_dotenv()

DATABASE_URL = os.getenv("DATABASE_URL")
